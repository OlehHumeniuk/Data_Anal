# %%
import keras
from keras import layers

import numpy as np
import random
import io

# %%
path = keras.utils.get_file(
    "THE OLD MAN AND THE SEA.txt",
    origin="https://archive.org/stream/TheOldManAndTheSea-Eng-Ernest/oldmansea_djvu.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://archive.org/stream/TheOldManAndTheSea-Eng-Ernest/oldmansea_djvu.txt
#    8192/Unknown - 0s 0us/stepCorpus length: 274770
# Total chars: 72
# Number of sequences: 91577

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(64),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
epochs = 10
batch_size = 256

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.5, 0.75, 1.0]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# 358/358 [==============================] - 38s 92ms/step - loss: 2.5199
#
# Generating text after epoch: 0
# ...Diversity: 0.5
# ...Generating with seed: "422?mt=12" data-event-click-tracking="to"
# ...Generated:  pn comaistanca-subnav-sealthe macknav-seaver an men and an and the sead sore bam siall and and ar the the les out and and stere the the srame the foth the tore cole tor le the wat he lar and as in seand cas ar in wor and and for the to sout wat the dom ther and and on in and and the style bor he he and and the sereen are tout the slere sode ar a in seard and and in the ald ole on an and ald canave
# -
# ...Diversity: 0.75
# ...Generating with seed: "422?mt=12" data-event-click-tracking="to"
# ...Generated:  plov: 2-s srea-?lablid" {                                    </dead=" the bes arall of ghem ald castret thet  teeir. hes har and be. beriok in me  the lare an all and  he men ole tale nor in the lore rat last, thenche las an a ala brem and an in borgreed and ing sos and an tlook subling.                   <                               <!--->           <mavel style-scope sayle-subla-lelin-s atham
# -
# ...Diversity: 1.0
# ...Generating with seed: "422?mt=12" data-event-click-tracking="to"
# ...Generated:  pjsrempinas waly or stand mat hin tos hgre the ceas slie' gers wal ttald and the sele had and ofg ga dted in and:. 0  .swen sous .fa bu in i tina digs" ltear. iit  on the ared borems bock te tre sxen trers im ay \archto od werid in the stwo alist gan glaimkrou?ky wot the area mas clay av the ou der. farm- bus newedrtine  fart lals the. gome tolan tat casd onere1t1 he kna-ss it thef bor 1     <ais
# -
# 358/358 [==============================] - 33s 92ms/step - loss: 1.8598
#
# Generating text after epoch: 1
# ...Diversity: 0.5
# ...Generating with seed: " to work on the docks loading sacks of s"
# ...Generated:  hark and him a can i cas a        "ha
# -
# ...Diversity: 0.75
# ...Generating with seed: " to work on the docks loading sacks of s"
# ...Generated:  here but whop, hav for he fas in the i ca the cond the a do the the cond breftre thous a dill the fish wiull mo drot the  the of is on the nat his the sland he shar.   bulling. be the ghat a daid the on the he cool bes, the .redia-stth he the  you con           </sly></media-scope class="prace com frepalase. cear-subnav,: 18828;     a-sia.: 1  .wayback-search: 0."stalliop: 1.6; }  .me-salia-sint-
# -
# ...Diversity: 1.0
# ...Generating with seed: " to work on the docks loading sacks of s"
# ...Generated:  till clissstslabeing thed the fimerit the sold he sto capeas ve was has heves tht mow alides thes wem.   "hi has  the 2hefe the3 on    kstyle ghe .scon whopers fislen whe sail for on jas hin berke. i cpaw the hhave.  he won he cliel the bicthes usc. ere was hor tha stay ut haver clorel =" dine the bemer thing a-'tid  the gir in that me  can an.   "   90 0 " fex ways back not he mask."     "he crem
# -
# 358/358 [==============================] - 33s 92ms/step - loss: 1.6536
#
# Generating text after epoch: 2
# ...Diversity: 0.5
# ...Generating with seed: "/li>       <!----><!---->         <li cl"
# ...Generated:  ass="style-scope media-subnav">           <a class="style-scope media-subnav"><!---->                 <!----><!----><!---->           <!----><!----><!---->           <!---->             <li class="style-scope media-button"><!--?lit$0008442403$-->all.search-slider of arilion."
# -
# ...Diversity: 0.75
# ...Generating with seed: "/li>       <!----><!---->         <li cl"
# ...Generated:  ass="sidle-slider style-scope wayback-search-1" have-signev" hadf="/a></li>           <a class="style-scope media-subnav" href="/detaresedwomscon thersiane" then a class and he of when the bees  he was [ 155] lerk the rack to  hid his low.   he doude on the sid he more and      he war and him gow you him he hadd if a could mont nor it was his sook and him on the pood it on the firch surfer was war
# -
# ...Diversity: 1.0
# ...Generating with seed: "/li>       <!----><!---->         <li cl"
# ...Generated:  ass="so class="style-scope media-subnav"><a                   <lid class="style-scope media-butty"><!-click-olacktome=" it="opgt/wasiter4e};     }     menor (       domemann donen againatiot and hishve the leenst fres, the purt.   he pouch un tam-.   thind it it ture him on he nothenter and heip. "wan in whef shat whev. inrochend to gondpee. gur to beg the forled keat held onstill  reltrot wher [2
# -
# 358/358 [==============================] - 33s 93ms/step - loss: 1.5414
#
# Generating text after epoch: 3
# ...Diversity: 0.5
# ...Generating with seed: "how many people will he feed, he thought"
# ...Generated:   he this he make of  he said. "i     the old man the fish and he and he came and he had of he that he fish his the shark and he hadd when again. it whine a and he sea  the eat and he said. "i the old man and he head sea the said. "i have of he took his the sia were he had and he had  and he was and he and the miding. he had and the old man the shark the still and the or of the old man the slean se
# -
# ...Diversity: 0.75
# ...Generating with seed: "how many people will he feed, he thought"
# ...Generated:  . the shand-hardel the get-inseld and in the fight and styon tom upid feat hand make in the old man faid and was did his mage. but heve he hid  whele sial yee and the hadd mary saided he deading in the stayrer the rake me of the had un were  grich and ches of the hiffer. if he had verinitine shork in the bog acone his deses and he had shand and he that he freal he fish of stroude. in it and dead i
# -
# ...Diversity: 1.0
# ...Generating with seed: "how many people will he feed, he thought"
# ...Generated:  .   the finew.no greit the wathatel.'of 'illand toathing. i the kigen have the sea fish unsthe spall anding/five.sid. thx hore it."   "i   "[610 net lecele. whine and weter  he made on his aly and youl ware. bucy hald in an alare waybeverbenbectsher hook till anyis he tianto noteas he digem and wall he that an av" the kit were  husled the suddesccectee searsed."  " he thoide. it is reairhove“ have
# -
# 358/358 [==============================] - 33s 93ms/step - loss: 1.4700
#
# Generating text after epoch: 4
# ...Diversity: 0.5
# ...Generating with seed: " hit the fish where he had already been "
# ...Generated:  the line  then he would shark the rade bone and the  was and the sea thought. the old man sea bows the old man sea       "
# -
# ...Diversity: 0.75
# ...Generating with seed: " hit the fish where he had already been "
# ...Generated:  of the  hand and ssilly des and the old man said.  the is fore then he the bott no back shown he stide fimed the skid said no tom he fish then when the fish strisk were the bor  he though and the old man storg the mine tear sea them strang the sas stidh not wine so lood no he     kright  the wake from sing tishe inculd the bom he wascester the undo the ald mank the cookster. shea ins as for the sa
# -
# ...Diversity: 1.0
# ...Generating with seed: " hit the fish where he had already been "
# ...Generated:  harg  shebes fresmon3 my the mand as finghtr is twing the old man a long he gove with and din up not lecongek them were out the bught, he sarbing, he wift, i classss"   [ 40  "i's thx estiol, freems mark his een.si   • 1s25] then in the moker the   he down with  they he was racky.    "id tre gaing, he tho leen they he dowat fave on  the old man's donghorged 7res onle lom erh  deed fo' wis down hee
# -
# 358/358 [==============================] - 35s 97ms/step - loss: 1.4216
#
# Generating text after epoch: 5
# ...Diversity: 0.5
# ...Generating with seed: "tv news</a>       <!----><!---->        "
# ...Generated:   <!--?lit$0008442403$--><!---->     <sition>
# -
# ...Diversity: 0.75
# ...Generating with seed: "tv news</a>       <!----><!---->        "
# ...Generated:     <a class="style-scope media-subnav"><a class="sead-medion olidion oles ilse="/detall/peidsownav) topnoveddomp1" class="style-scope media-subnav"><a class="style-scope primary-ia-trop'slin">                       <a class="style-scope media-subnav"><a class="style-scope media-subnav" himp=" ditn: heme.wayback-slider">       <sclitimint="luittopempxislibelublabkitsiingoutidded;     [8 1.7-20355
# -
# ...Diversity: 1.0
# ...Generating with seed: "tv news</a>       <!----><!---->        "
# ...Generated:   <sutinstlis s="p1512224hre" fanlin="5;   , stop: noritlolion {   dint-lackgoouthouslogh.dimaln-sodita-evidiong-buttrmenu="painerefold/usluddownuseidboxtoproursinnutenoblacesenpsplobemtypeimary il.j3yslickttom. holdsteralliminger hime=warthtwa,">           cous: id.search-menu-1 .media-button-1 .menu--coput-1 .archox; mediangex;       @mlin-1"><asching="topnav|ariasialloddung" centwifte="|maderchi
# -
# 358/358 [==============================] - 35s 97ms/step - loss: 1.3797
#
# Generating text after epoch: 6
# ...Diversity: 0.5
# ...Generating with seed: "                                       |"
# ...Generated:  machiov: 1.5rem.media-subnav {   top: 0;     way: 0 1; }  .media-subnav-1 .icon-have.media-button { .media-subnav {   padding-align: fonthe; }  .nav-search {   thanstit-alige: ble warestine style-slider sia-eling thircent"></span>           </li><!---->         <li class="style-scope media-subnav"><a class="style-scope media-subnav" href="/details/spansedayseracent" data-event-click-tracking="topn
# -
# ...Diversity: 0.75
# ...Generating with seed: "                                       |"
# ...Generated:  marchiov.sit {   margin-putimation: navia-idon" data-event-click-tracking="topnav|formasibvenut{                                                                                                                            |laffia-clipchrorter contery caslins="style-scope media-subnav"><a class="style-scope media-subnav">         </sclipk"><a class="style-scope media-subnav" href="/details/deswarccim
# -
# ...Diversity: 1.0
# ...Generating with seed: "                                       |"
# ...Generated:  mautiveserel topescopanagesecatercermagrimisc" tylescompard" fill="inatehingom">       </svg>            </lli></l>       </s3ab supth="ht*ms: 8307n;     tlongin-.leden: norm .o3on2: 1; }   tlima-igion: ffftt: 910px fill.spadisedione;    sconter: yon-1" denanfty="nhutine'sliw" dapa-</a></li>           <!--?lit$0008442403$--><storitwy</span>           <!--?lit$0008442403$-->it olffus fincu {   <us
# -
# 358/358 [==============================] - 33s 93ms/step - loss: 1.3497
#
# Generating text after epoch: 7
# ...Diversity: 0.5
# ...Generating with seed: "tance to the fish to  the skiff itself. "
# ...Generated:  the old man stranger on it the strange was fast the  stranged and the strene some it in the back to pare well and the sea   he said he thought. the boy some on the boy the boy thought.   "he made  stilld the slooked the stranged in the bolls he that         the plook only down the lines to there and and the wash him the boy stry and the sea    he thought to gettill the sea     the strened and the
# -
# ...Diversity: 0.75
# ...Generating with seed: "tance to the fish to  the skiff itself. "
# ...Generated:  dow intingway beed the swaschid the tard the old man forth to and the shark put  slooked the sea        -    - - 6 - -      |abol a> shack andesfars tex dayped the slaftress the stimp. the base of that thing all them too  ghats it.   the sing the old man had the boigh, the man would soo, had    most the sight dood and shoulder with said. "i hand hishhack on the ming or the ming some he sea  comg t
# -
# ...Diversity: 1.0
# ...Generating with seed: "tance to the fish to  the skiff itself. "
# ...Generated:  a good and that out mand the ght. b'y white the ragaig."   he don'ther his lefe ald mentins and the wathord.    man's his conly fash the foll know  shold not ged. 'le ond pataght. shou make a neen.   "9 is," dotthorrds the ming of his his sea pled in when one to his rese like and, in bead sloed hanks pulled and the batk end rade. that in he there his hee' do now the noth and tyough under to iod. [
# -
# 358/358 [==============================] - 35s 98ms/step - loss: 1.3204
#
# Generating text after epoch: 8
# ...Diversity: 0.5
# ...Generating with seed: " 1.5724492-2.512298 2.63065-.591311-1.05"
# ...Generated:  053779-2.85255479-.000069.1806706-.0880377-.0599126 0-.050192 1.0701883.2017777-.000026-.000121-.0000 g lidivintusetinutivens.searchime; }  }  @media-mugia-subnav-1 .search-inconten.spadiget.media-button: conterderadion: 1.2rem;     thanm-sizn: 1;       widt-an-wicmd/active.org/led.media-button {   display: block;     waybaca-ev-nat-- .udea-menu-1 .search-arfform nonat-buter {   display: none; }
# -
# ...Diversity: 0.75
# ...Generating with seed: " 1.5724492-2.512298 2.63065-.591311-1.05"
# ...Generated:  67897,22.58619859-2.199167-.0139263-.679962 3.7830569-5.8979611-.711866-.000566-.0292077.0300767-.2529765-.0078613-.0305882.0279167-.7058823-.278617-.0917771.215861-.2829188.0121812 l2.0507186-1.0618861-1.73358073-3.86428677.0294661-1.5757284-1.0968228 -1.1393239-.0214871-.6711186h.019821-.0526667-1.5890394-1.0530671,5.1715-141-.470171 1.870182 2.0306921-.06577992 7.435767 0 .0179163.16374038-.617
# -
# ...Diversity: 1.0
# ...Generating with seed: " 1.5724492-2.512298 2.63065-.591311-1.05"
# ...Generated:  7787.115361-2.21626-1.0978894-5.5-1185-1.436347v3 0 7.07333711-.0400161-2.2545558l2.0805661-l1.9369308/352429.5251727.0032939-.005881-.05824/9-5.706817-.0124362-0.42858v2-.029572-4.521198 2.2560398-1.9746298-.0559698v-3.489465-.1311712zm-3.9462395 5.00779983.3879561-.2778123l2.4316699.0290515v-4.594536,1.0404902-5.3017351vcl4.67717996-.907663,0-.677778219 31.2357765 -.0405883-.4907966.16787698-.17
# -
# 358/358 [==============================] - 35s 98ms/step - loss: 1.3001
#
# Generating text after epoch: 9
# ...Diversity: 0.5
# ...Generating with seed: "that shows on the surface today travels "
# ...Generated:  stronged and man too  be the sail and he wish the old man said. "i was a can the old man soot he was wasted. the old man nother the  said. "i must and he taper and should someto  the wand he that terting move in the bow he said. "i must the  see the old man said. "but the old man soot the old man should his line in the  some when he thought. the botting   "he miny     the old man were be that this
# -
# ...Diversity: 0.75
# ...Generating with seed: "that shows on the surface today travels "
# ...Generated:  tor leve that he pathers whill nothere the right discen.   "i'll all the  werengy water. the bow and he donding. then wente menuse were  brow been the line speed it was badd of the tones downs, the sea in light him forgoid somoth. ellushed line see the could pain he was soo's will of the man shark the old man trimp sall will the old man lathing man till of frow the bottire, butle on the loons even
# -
# ...Diversity: 1.0
# ...Generating with seed: "that shows on the surface today travels "
# ...Generated:  fash to looks niving it ins.   the line be clave in the winds beting fost puct have tirgts, nowned he  he wlothorts one i courps yeve-liben of ti ding, sait. womeny. i can is 'sore were to 6ily wereed coulding jumped whine the colloke, anotrocot   miteling  stridp   have in, becked noight make toom the pulted. with the plow slyamp meats of and the hid tat of  the lashided. the dolpsed as brousided
# -

# %% [markdown]
# Task 2

# %%
# Transformers installation
#pip install transformers

from transformers import pipeline
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
txt_1 = 'She said, Come on, baby, you got a license for love And if it expires, I pray help from above'
classifier(txt_1)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9927563071250916}]

# %%
txt_2 = 'I said, What set you free and brought you to me, babe? What set you free? I need you here by me'
classifier(txt_2)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9916378855705261}]

# %%
txt_1_ukr = 'Жити чи не жити Ось в чому питання'
classifier(txt_1_ukr)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.704511821269989}]

# %%
txt_2_ukr = 'всебічний'
classifier(txt_2_ukr)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9462901949882507}]

# %% [markdown]
# UKRAINIAN MODEL

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %%
sentences = ['Краса лиця це половина приданого', 'Хоч не з красою аби з головою']

# %%
tokenizer = AutoTokenizer.from_pretrained('ukr-models/lb-2')
model = AutoModel.from_pretrained('ukr-models/lb-2')
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/222k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/702k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/744 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# %%
with torch.no_grad():
    model_output = model(**encoded_input)

# %%
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# %%
print("Sentence embeddings:")
print(sentence_embeddings)
# Out:
# Sentence embeddings:
# tensor([[-0.0816,  0.0302, -0.4180,  ..., -0.3952,  0.0433,  0.1311],
#         [-0.0154,  0.2198, -0.2849,  ..., -0.6855,  0.0617,  0.2201]])

# %% [markdown]
# Task 3

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
import numpy as np
import tensorflow as tf
from keras.applications import vgg19

base_image_path = keras.utils.get_file("army.jpg", "https://i.imgur.com/tZs7k2r.jpeg")
style_reference_image_path = keras.utils.get_file(
    "small_city.jpg", "https://i.imgur.com/5yeBVeM.jpeg"
)
result_prefix = "paris_generated"

# Weights of the different loss components
total_variation_weight = 1e-6
style_weight = 1e-6
content_weight = 2.5e-8

# Dimensions of the generated picture.
width, height = keras.utils.load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)
# Out:
# Downloading data from https://i.imgur.com/tZs7k2r.jpeg
# 48691/48691 [==============================] - 0s 0us/step
# Downloading data from https://i.imgur.com/5yeBVeM.jpeg
# 805461/805461 [==============================] - 0s 0us/step

# %%
from IPython.display import Image, display

display(Image(base_image_path))
display(Image(style_reference_image_path))

# %%
def preprocess_image(image_path):
    # Util function to open, resize and format pictures into appropriate tensors
    img = keras.utils.load_img(image_path, target_size=(img_nrows, img_ncols))
    img = keras.utils.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return tf.convert_to_tensor(img)


def deprocess_image(x):
    # Util function to convert a tensor into a valid image
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype("uint8")
    return x

# %%
def gram_matrix(x):
    x = tf.transpose(x, (2, 0, 1))
    features = tf.reshape(x, (tf.shape(x)[0], -1))
    gram = tf.matmul(features, tf.transpose(features))
    return gram


# The "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image


def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return tf.reduce_sum(tf.square(S - C)) / (4.0 * (channels**2) * (size**2))


# An auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image


def content_loss(base, combination):
    return tf.reduce_sum(tf.square(combination - base))


# The 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent


def total_variation_loss(x):
    a = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, 1:, : img_ncols - 1, :]
    )
    b = tf.square(
        x[:, : img_nrows - 1, : img_ncols - 1, :] - x[:, : img_nrows - 1, 1:, :]
    )
    return tf.reduce_sum(tf.pow(a + b, 1.25))

# %%
# Build a VGG19 model loaded with pre-trained ImageNet weights
model = vgg19.VGG19(weights="imagenet", include_top=False)

# Get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# Set up a model that returns the activation values for every layer in
# VGG19 (as a dict).
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
style_layer_names = [
    "block1_conv1",
    "block2_conv1",
    "block3_conv1",
    "block4_conv1",
    "block5_conv1",
]
# The layer to use for the content loss.
content_layer_name = "block5_conv2"


def compute_loss(combination_image, base_image, style_reference_image):
    input_tensor = tf.concat(
        [base_image, style_reference_image, combination_image], axis=0
    )
    features = feature_extractor(input_tensor)

    # Initialize the loss
    loss = tf.zeros(shape=())

    # Add content loss
    layer_features = features[content_layer_name]
    base_image_features = layer_features[0, :, :, :]
    combination_features = layer_features[2, :, :, :]
    loss = loss + content_weight * content_loss(
        base_image_features, combination_features
    )
    # Add style loss
    for layer_name in style_layer_names:
        layer_features = features[layer_name]
        style_reference_features = layer_features[1, :, :, :]
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features)
        loss += (style_weight / len(style_layer_names)) * sl

    # Add total variation loss
    loss += total_variation_weight * total_variation_loss(combination_image)
    return loss

# %%
@tf.function
def compute_loss_and_grads(combination_image, base_image, style_reference_image):
    with tf.GradientTape() as tape:
        loss = compute_loss(combination_image, base_image, style_reference_image)
    grads = tape.gradient(loss, combination_image)
    return loss, grads

# %%
optimizer = keras.optimizers.SGD(
    keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96
    )
)

base_image = preprocess_image(base_image_path)
style_reference_image = preprocess_image(style_reference_image_path)
combination_image = tf.Variable(preprocess_image(base_image_path))

iterations = 100
for i in range(1, iterations + 1):
    loss, grads = compute_loss_and_grads(
        combination_image, base_image, style_reference_image
    )
    optimizer.apply_gradients([(grads, combination_image)])
    if i % 10 == 0:
        print("Iteration %d: loss=%.2f" % (i, loss))
        img = deprocess_image(combination_image.numpy())
        fname = result_prefix + "_at_iteration_%d.png" % i
        keras.utils.save_img(fname, img)
# Out:
# Iteration 10: loss=10060.30
# Iteration 20: loss=7786.35
# Iteration 30: loss=6822.97
# Iteration 40: loss=6188.69
# Iteration 50: loss=5716.20
# Iteration 60: loss=5344.75
# Iteration 70: loss=5041.37
# Iteration 80: loss=4788.50
# Iteration 90: loss=4573.44
# Iteration 100: loss=4387.86

# %%
display(Image(result_prefix + "_at_iteration_100.png"))
